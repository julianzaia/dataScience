# %%
# !pip install yfinance
# !pip3 install pandas_datareader
# !pip install --upgrade pandas-datareader
import pandas_datareader 
import pandas_datareader as web
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import yfinance as yf

from matplotlib import pyplot as plt

import seaborn as sns
import datetime as dt

# %%
sp500url= 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'

# %%
data_table= pd.read_html(sp500url)

# %%
tickers= data_table[0]['Symbol'].tolist()
colnames = []

# %%
tickers
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'ADP',
#  'AAP',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AMD',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'WRB',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BG',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
# ...

# %%
start='2022-01-01'
end='2023-05-15'

# %%
# Get a list of all blue chip stocks
blue_chips = ["MMM" ,"GOOGL", "AMZN" , "AXP","AAPL","BAC","KO","COST","DIS","GS","HD","IBM","JNJ","MCD","MSFT","NKE","SBUX","VZ","V","WMT"]

# %%
blue_chips
# Out:
# ['MMM',
#  'GOOGL',
#  'AMZN',
#  'AXP',
#  'AAPL',
#  'BAC',
#  'KO',
#  'COST',
#  'DIS',
#  'GS',
#  'HD',
#  'IBM',
#  'JNJ',
#  'MCD',
#  'MSFT',
#  'NKE',
#  'SBUX',
#  'VZ',
#  'V',
#  'WMT']

# %%
# //Warren Buffett - Berkshire Hathaway //
#tickers1= [ 'AXP', 'AAPL', 'BAC', 'CVX', 'KO', 'OXY', 'KHC', 'MCO', 'TSM', 'USB', 'HPQ', 'BK', 'C']
#// MY PERSONAL PORTFOLIO// DATE= 2022-11-12
#tickers1=['GOOGL','META', 'TSM', 'OXY', 'CVX','DIS', 'AMZN']
#tickers1=['BAC',	'WFC',	'BABA',	'USB',	'PKX']

# %%
spPrices= yf.download(blue_chips, start,end)['Adj Close']
# Out:
# [*********************100%***********************]  20 of 20 completed

# %%
combined= spPrices

# %%
data_return= np.log(1+spPrices.pct_change())

# %%
data_return.head()
# Out:
#                 AAPL      AMZN       AXP       BAC      COST       DIS  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.012773 -0.017060  0.031598  0.038446 -0.004386 -0.006592
# 2022-01-05 -0.026960 -0.019074 -0.010713 -0.017023 -0.025689 -0.003474
# 2022-01-06 -0.016834 -0.006734  0.009122  0.019936 -0.000218  0.010958
# 2022-01-07  0.000988 -0.004297  0.008524  0.021581 -0.025085  0.005910
#
#                GOOGL        GS        HD       IBM       JNJ        KO  \
# Date
# 2022-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2022-01-04 -0.004091  0.030271  0.010225  0.014450 -0.002685  0.016557
# 2022-01-05 -0.046962 -0.021958 -0.013657  0.001448  0.006641  0.008259
# 2022-01-06 -0.000200 -0.004274 -0.003641 -0.021057 -0.003432 -0.005278
# 2022-01-07 -0.005317  0.001460 -0.030401 -0.003775  0.013427 -0.002318
#
#                  MCD       MMM      MSFT       NKE      SBUX         V  \
# Date
# ...

# %%
correlation =data_return.corr()

# %%
covariance = data_return.cov()

# %%
correlation
# Out:
#            AAPL      AMZN       AXP       BAC      COST       DIS     GOOGL  \
# AAPL   1.000000  0.667102  0.610715  0.519435  0.617153  0.621521  0.753725
# AMZN   0.667102  1.000000  0.519297  0.486948  0.548122  0.622173  0.707623
# AXP    0.610715  0.519297  1.000000  0.708289  0.443457  0.587396  0.499658
# BAC    0.519435  0.486948  0.708289  1.000000  0.384467  0.566978  0.468997
# COST   0.617153  0.548122  0.443457  0.384467  1.000000  0.432329  0.528320
# DIS    0.621521  0.622173  0.587396  0.566978  0.432329  1.000000  0.554966
# GOOGL  0.753725  0.707623  0.499658  0.468997  0.528320  0.554966  1.000000
# GS     0.564431  0.539394  0.648618  0.765125  0.435503  0.580340  0.518485
# HD     0.582323  0.555465  0.482231  0.436308  0.615833  0.515295  0.520296
# IBM    0.457853  0.283469  0.445915  0.442366  0.416462  0.311412  0.328495
# JNJ    0.336448  0.202888  0.254092  0.278430  0.370967  0.210821  0.242492
# ...

# %%
plt.figure(figsize=(18,9))
sns.heatmap(correlation, cmap="coolwarm")
# Out:
# <Axes: >
