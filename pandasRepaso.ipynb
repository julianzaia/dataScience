# %% [markdown]
# <a href="https://colab.research.google.com/github/julianzaia/dataScience/blob/main/pandasRepaso.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.9f' % x)
pd.set_option('display.max_columns', None)


import numpy as np

import seaborn as sns 
sns.set()

import matplotlib
import matplotlib.pyplot as plt
from google.colab import drive
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
drive.mount("/content/drive")
contentFolder = "/content/drive/MyDrive/PandasEjercicios"
if not os.path.exists(contentFolder):
    os.mkdir(contentFolder)
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("{}/pokemon.csv".format(contentFolder), sep=",")

# %%
print(df.columns)
print(df.head(4))
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']  1.000000000   1.000000000     1.000000000
# 1  ['Overgrow', 'Chlorophyll']  1.000000000   1.000000000     1.000000000
# ...

# %%
df.iloc[1:2]
print(df.iloc[0:1])
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']  1.000000000   1.000000000     1.000000000
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0       0.500000000    0.500000000    0.500000000   2.000000000
#
#    against_flying  against_ghost  against_grass  against_ground  against_ice  \
# 0     2.000000000    1.000000000    0.250000000     1.000000000  2.000000000
#
#    against_normal  against_poison  against_psychic  against_rock  \
# 0     1.000000000     1.000000000      2.000000000   1.000000000
#
#    against_steel  against_water  attack  base_egg_steps  base_happiness  \
# 0    1.000000000    0.500000000      49            5120              70
#
#    base_total capture_rate classfication  defense  experience_growth  \
# 0         318           45  Seed Pokémon       49            1059860
#
#      height_m  hp     japanese_name       name  percentage_male  \
# ...

# %%
for index, row in df.iterrows():
  print(index, row['type1'])
# Out:
# 0 grass
# 1 grass
# 2 grass
# 3 fire
# 4 fire
# 5 fire
# 6 water
# 7 water
# 8 water
# 9 bug
# 10 bug
# 11 bug
# 12 bug
# 13 bug
# 14 bug
# 15 normal
# 16 normal
# 17 normal
# 18 normal
# 19 normal
# 20 normal
# 21 normal
# 22 poison
# 23 poison
# 24 electric
# 25 electric
# 26 ground
# 27 ground
# 28 poison
# 29 poison
# 30 poison
# 31 poison
# 32 poison
# 33 poison
# 34 fairy
# 35 fairy
# 36 fire
# 37 fire
# 38 normal
# 39 normal
# 40 poison
# 41 poison
# 42 grass
# 43 grass
# 44 grass
# 45 bug
# 46 bug
# 47 bug
# 48 bug
# 49 ground
# 50 ground
# 51 normal
# 52 normal
# 53 water
# 54 water
# 55 fighting
# 56 fighting
# 57 fire
# 58 fire
# 59 water
# 60 water
# 61 water
# 62 psychic
# 63 psychic
# 64 psychic
# 65 fighting
# 66 fighting
# 67 fighting
# 68 grass
# 69 grass
# 70 grass
# 71 water
# 72 water
# 73 rock
# 74 rock
# 75 rock
# 76 fire
# 77 fire
# 78 water
# 79 water
# 80 electric
# 81 electric
# 82 normal
# 83 normal
# 84 normal
# 85 water
# 86 water
# 87 poison
# 88 poison
# ...

# %%
df.loc[df['type1'] == 'grass']
# Out:
#                                            abilities  against_bug  \
# 0                        ['Overgrow', 'Chlorophyll']  1.000000000
# 1                        ['Overgrow', 'Chlorophyll']  1.000000000
# 2                        ['Overgrow', 'Chlorophyll']  1.000000000
# 42                       ['Chlorophyll', 'Run Away']  1.000000000
# 43                         ['Chlorophyll', 'Stench']  1.000000000
# ..                                               ...          ...
# 760        ['Leaf Guard', 'Oblivious', 'Sweet Veil']  2.000000000
# 761        ['Leaf Guard', 'Oblivious', 'Sweet Veil']  2.000000000
# 762  ['Leaf Guard', 'Queenly Majesty', 'Sweet Veil']  2.000000000
# 786                    ['Grassy Surge', 'Telepathy']  1.000000000
# 797                                  ['Beast Boost']  1.000000000
#
#      against_dark  against_dragon  against_electric  against_fairy  \
# 0     1.000000000     1.000000000       0.500000000    0.500000000
# ...

# %%
#df.sort_values('name')
df.sort_values('type1', ascending= False)
# Out:
#                                          abilities  against_bug  against_dark  \
# 78       ['Oblivious', 'Own Tempo', 'Regenerator']  2.000000000   2.000000000
# 365                     ['Shell Armor', 'Rattled']  1.000000000   1.000000000
# 90       ['Shell Armor', 'Skill Link', 'Overcoat']  1.000000000   1.000000000
# 210   ['Poison Point', 'Swift Swim', 'Intimidate']  0.500000000   1.000000000
# 417                   ['Swift Swim', 'Water Veil']  1.000000000   1.000000000
# ..                                             ...          ...           ...
# 742  ['Honey Gather', 'Shield Dust', 'Sweet Veil']  0.500000000   0.500000000
# 741  ['Honey Gather', 'Shield Dust', 'Sweet Veil']  0.500000000   0.500000000
# 595           ['Compoundeyes', 'Unnerve', 'Swarm']  1.000000000   1.000000000
# 737                                   ['Levitate']  1.000000000   1.000000000
# 400                      ['Shed Skin', 'Run Away']  1.000000000   1.000000000
#
# ...

# %%
df.sort_values('type1', ascending= False, axis=0)
# Out:
#                                          abilities  against_bug  against_dark  \
# 78       ['Oblivious', 'Own Tempo', 'Regenerator']  2.000000000   2.000000000
# 365                     ['Shell Armor', 'Rattled']  1.000000000   1.000000000
# 90       ['Shell Armor', 'Skill Link', 'Overcoat']  1.000000000   1.000000000
# 210   ['Poison Point', 'Swift Swim', 'Intimidate']  0.500000000   1.000000000
# 417                   ['Swift Swim', 'Water Veil']  1.000000000   1.000000000
# ..                                             ...          ...           ...
# 742  ['Honey Gather', 'Shield Dust', 'Sweet Veil']  0.500000000   0.500000000
# 741  ['Honey Gather', 'Shield Dust', 'Sweet Veil']  0.500000000   0.500000000
# 595           ['Compoundeyes', 'Unnerve', 'Swarm']  1.000000000   1.000000000
# 737                                   ['Levitate']  1.000000000   1.000000000
# 400                      ['Shed Skin', 'Run Away']  1.000000000   1.000000000
#
# ...

# %%
new_df = df.loc[(df['type2' == 'grass'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import re

# %%
df.loc[~df['type2'].str.contains('NaN', flags=re.I, regex=True)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-8bfb29f5c694> in <module>
# ----> 1 df.loc[~df['type2'].str.contains('NaN', flags=re.I, regex=True)]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __invert__(self)
#    1530             return self
#    1531
# -> 1532         new_data = self._mgr.apply(operator.invert)
#    1533         return self._constructor(new_data).__finalize__(self, method="__invert__")
#    1534
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     323             try:
#     324                 if callable(f):
# --> 325                     applied = b.apply(f, **kwargs)
#     326                 else:
#     327                     applied = getattr(b, f)(**kwargs)
#
# ...

# %%
#df.sort_values('type1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-f2d0e7fc04e5> in <module>
# ----> 1 df.sort_values('type1')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6257
#    6258             by = by[0]
# -> 6259             k = self._get_label_or_level_values(by, axis=axis)
#    6260
#    6261             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
# ...

# %%
df = df.drop(columns= 'type1')

# %%
print(df.name)
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 796    Celesteela
# 797       Kartana
# 798      Guzzlord
# 799      Necrozma
# 800      Magearna
# Name: name, Length: 801, dtype: object
